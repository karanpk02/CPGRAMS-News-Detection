# %%
import csv

# %%
#Creating csv files.
fields = ['News', 'Relevence']
filename = "/content/drive/MyDrive/Colab Notebooks/news.csv"
with open(filename, 'w') as csvfile:
	writer = csv.DictWriter(csvfile, fieldnames = fields)
	writer.writeheader()

# %%
#for appending
from csv import writer
filename = "/content/drive/MyDrive/Colab Notebooks/news.csv"
with open(filename, 'a+', newline='') as f:
        # Create a writer object from csv module
        csv_writer = writer(f)
        # Add contents of list as last row in the csv file
        csv_writer.writerow([input(), "no"])
# Out:
# Undoubtedly I am proud of the country for sustaining its independence for 75 years, but I can really not stop myself from thinking about whether we are really independent. Do women have the freedom to walk the streets of this country sans the fear of being sexually assaulted? Every time I believe that things finally might be changing for the better, the state and people lower the bar. So on the day meant to celebrate our country’s independent status and achievements, some people in Godhra were distributing sweets to mark the release of 11 men convicted in the Bilkis Bano case.

# %%
import pandas as pd
df = pd.read_csv('/content/drive/MyDrive/Colab Notebooks/news.csv')
df.head()
# Out:
#                                                 News Relevence
# 0  The causes of road accidents are several and o...       yes
# 1  The government says the number of accidents, d...       yes
# 2  Measures like weeding out bogus driving licenc...       yes
# 3  The Road Accidents in India 2018 report by the...       yes
# 4  A senior Delhi Police official said road liter...       yes

# %%
df.shape
# Out:
# (391, 2)

# %%
from sklearn.utils import shuffle
df = shuffle(df)

# %%
df
# Out:
#                                                   News Relevence
# 70   Broken pathways, waterlogged pockets and long ...       yes
# 15   Local train services on the Harbour Line in Mu...       yes
# 42   @IRCTCofficial we boarded 12016 Shatabdi expre...       yes
# 31   Indian Railways will carry out the mega block ...       yes
# 379  Swarnam Karipur Vima tried to bypass customs a...        no
# ..                                                 ...       ...
# 171  Recent events confirm the general perception t...       yes
# 378  Tuniram Madri received a goat as a prize in th...        no
# 20   In the din over the armed forces’ Agnipath rec...       yes
# 355  A report today says that Apple is ahead of mos...        no
# 240  According to PIL of Dilip Baral, the case is u...        no
#
# [391 rows x 2 columns]

# %%
df = df.reset_index()
df
# Out:
#      index                                               News Relevence
# 0       70  Broken pathways, waterlogged pockets and long ...       yes
# 1       15  Local train services on the Harbour Line in Mu...       yes
# 2       42  @IRCTCofficial we boarded 12016 Shatabdi expre...       yes
# 3       31  Indian Railways will carry out the mega block ...       yes
# 4      379  Swarnam Karipur Vima tried to bypass customs a...        no
# ..     ...                                                ...       ...
# 386    171  Recent events confirm the general perception t...       yes
# 387    378  Tuniram Madri received a goat as a prize in th...        no
# 388     20  In the din over the armed forces’ Agnipath rec...       yes
# 389    355  A report today says that Apple is ahead of mos...        no
# 390    240  According to PIL of Dilip Baral, the case is u...        no
#
# [391 rows x 3 columns]

# %%
del df['index']
df
# Out:
#                                                   News Relevence
# 0    Broken pathways, waterlogged pockets and long ...       yes
# 1    Local train services on the Harbour Line in Mu...       yes
# 2    @IRCTCofficial we boarded 12016 Shatabdi expre...       yes
# 3    Indian Railways will carry out the mega block ...       yes
# 4    Swarnam Karipur Vima tried to bypass customs a...        no
# ..                                                 ...       ...
# 386  Recent events confirm the general perception t...       yes
# 387  Tuniram Madri received a goat as a prize in th...        no
# 388  In the din over the armed forces’ Agnipath rec...       yes
# 389  A report today says that Apple is ahead of mos...        no
# 390  According to PIL of Dilip Baral, the case is u...        no
#
# [391 rows x 2 columns]

# %%
df.rename(columns = {'Relevence':'Relevance'}, inplace = True)
df
# Out:
#                                                   News Relevance
# 0    Broken pathways, waterlogged pockets and long ...       yes
# 1    Local train services on the Harbour Line in Mu...       yes
# 2    @IRCTCofficial we boarded 12016 Shatabdi expre...       yes
# 3    Indian Railways will carry out the mega block ...       yes
# 4    Swarnam Karipur Vima tried to bypass customs a...        no
# ..                                                 ...       ...
# 386  Recent events confirm the general perception t...       yes
# 387  Tuniram Madri received a goat as a prize in th...        no
# 388  In the din over the armed forces’ Agnipath rec...       yes
# 389  A report today says that Apple is ahead of mos...        no
# 390  According to PIL of Dilip Baral, the case is u...        no
#
# [391 rows x 2 columns]

# %%
df.to_csv('News_relevance.csv', index=False)

# %%
from csv import writer
filename = "/content/drive/MyDrive/Colab Notebooks/news.csv"
with open(filename, 'a+', newline='') as f:
        # Create a writer object from csv module
        csv_writer = writer(f)
        # Add contents of list as last row in the csv file
        csv_writer.writerow([input(), "no"])
